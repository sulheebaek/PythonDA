# %%
import pandas as pd

# %%
# !dir AAL.csv
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 32CB-3CE9
#
#  C:\poscoict 디렉터리
# 파일을 찾을 수 없습니다.

# %%
aapl = pd.read_csv('AAP.csv', index_col='Date')

# %%
pd.read_csv?

# %%
aapl
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-12-12  101.709999  105.559998  101.709999  103.029999  102.832932
# 2017-12-13  103.629997  103.720001  101.860001  102.500000  102.303940
# 2017-12-14  103.230003  103.900002   99.769997  100.199997  100.008339
# 2017-12-15  100.839996  101.720001  100.169998  100.699997  100.507385
# 2017-12-18  101.339996  103.099998  100.650002  102.709999  102.513542
# 2017-12-19  102.449997  102.860001   99.389999   99.730003   99.539246
# 2017-12-20  100.029999  100.910004   98.029999   98.589996   98.401413
# 2017-12-21   98.510002  100.519997   98.199997  100.129997   99.999321
# 2017-12-22  100.639999  100.830002   99.709999  100.550003  100.418785
# 2017-12-26  100.800003  102.750000  100.650002  101.959999  101.826935
# 2017-12-27  101.720001  101.720001   99.400002   99.769997   99.639793
# 2017-12-28   99.860001   99.910004   98.169998   99.709999   99.579880
# ...

# %%
returns = aapl.pct_change()
returns.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2017-12-12       NaN       NaN       NaN       NaN        NaN       NaN
# 2017-12-13  0.018877 -0.017431  0.001475 -0.005144  -0.005144 -0.552448
# 2017-12-14 -0.003860  0.001735 -0.020518 -0.022439  -0.022439  0.016741
# 2017-12-15 -0.023152 -0.020982  0.004009  0.004990   0.004990  0.454922
# 2017-12-18  0.004958  0.013567  0.004792  0.019960   0.019960 -0.477551

# %% [markdown]
# 상관관계

# %%
returns['Open'].corr(returns['Volume'])
# Out:
# 0.21535354330853645

# %% [markdown]
# 공분산

# %%
returns['Open'].cov(returns['Volume'])
# Out:
# 0.002048839864081404

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(returns['Open'], returns['Volume'])

# %%
plt.scatter(returns['High'], returns['Volume'])

# %%
returns.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.680489  0.619307  0.182413   0.182312  0.215354
# High       0.680489  1.000000  0.623392  0.582802   0.582738  0.385251
# Low        0.619307  0.623392  1.000000  0.633391   0.633292 -0.038396
# Close      0.182413  0.582802  0.633391  1.000000   0.999995  0.093358
# Adj Close  0.182312  0.582738  0.633292  0.999995   1.000000  0.093367
# Volume     0.215354  0.385251 -0.038396  0.093358   0.093367  1.000000

# %%
returns[1:].High.rolling(180).mean().plot()
returns[1:].High.rolling(180).mean().plot()
